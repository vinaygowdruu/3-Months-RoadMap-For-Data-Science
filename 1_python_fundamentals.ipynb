# %% [markdown]
# <a href="https://colab.research.google.com/github/vinaygowdruu/3-Months-RoadMap-For-Data-Science/blob/main/1_python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Python Output

# %%
# Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print('salman khan')
# Out:
# salman khan

# %%
print(salman khan)
# Out:
#   File "<ipython-input-3-0713073d8d88>", line 1
#     print(salman khan)
#                     ^
# SyntaxError: invalid syntax

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('hello')
print('world')
print()
# Out:
# hello
# world

# %%
print('world',end='-')
print('hello',end='-')
# Out:
# world-hello-

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5+6j)

# Never used it in Project
# Out:
# (5+6j)

# %%
# List-> In C its called Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary it is key value Pair
print({'name':'Nitish','gender':'Male','weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %%
# type
type([1,2,3])
# Out:
# list

# %% [markdown]
# # 3. Variables

# %%
#Why?
 #Its there to store the value


# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
name = 'nitish'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# nitish
# 11

# %%
# Dynamic Typing
    #No need to priorly declare the data type
    #data type is not attached with variable name
a = 5
# Static Typing (Python does not use explicit type declarations like 'int a = 5')
a = 5
# Out:
#   File "/tmp/ipykernel_2953/113884285.py", line 5
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
# Dynamic Binding
a = 5
print(a)
a = 'nitish'
print(a)

# Static Binding
int a = 5
# Out:
# 5
# nitish

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords

True, False, None and, or, not, in, if, elif, else Loops for, while, break, continue, return, lambda, yield, from, except, finally, raise, del, global, await

# %%
# Identifiers
# You can't start with a digit
name1 = 'Vinay'
print(name1)
# You can use special chars -> _ (Underscore) NOT any other Special Characters
_ = 'Vinaay'
f_name='Vin'
f-name = 'Rashiv' #Compilation error
print(_)
# identiers can not be keyword
# Out:
#   File "/tmp/ipykernel_4919/3020754621.py", line 8
#     f-name = 'Rashiv'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# # Temp Heading

# %% [markdown]
# #thr
# #New section

# %% [markdown]
# # 5. User Input

# %%
# Static Vs Dynamic
input('Enter Email')
input()
# Out:
# Enter Emailhi
# dk
# 'dk'

# %%
# take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
#print(type(fnum),type(snum))
# add the 2 variables
#result = fnum + snum
# print the result
print(f'Result is {fnum + snum}')
print(type(fnum))
# Out:
# enter first number2
# enter second number2
# Result is 4
# <class 'int'>

# %% [markdown]
# # 6. Type Conversion

# %%
# Implicit Vs Explicit

#Implicit
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
# Explicit
# str -> int
#int(4+5j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %% [markdown]
# # 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)

# %%
# binary
x = 3.14j
print(x.imag)
print(x)
# Out:
# 3.14
# 3.14j

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
k = None
print(k)
#Usecase if u want to use any variable for future usage

a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# # 8. Operators

# %%
# Arithmetic
# Relational
# Logical
# Bitwise
# Assignment
# Membership

# %% [markdown]
# # 9. If-Else
